# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashveenk200/Stock-market-price-prediction-/blob/main/stock_markrt_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 2
# ##**stock_price prediction**
# ![0_JhQln53nvsJNM7-c.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
df=pd.read_csv('/content/drive/MyDrive/badmash company/stock market prediction /stock market prediction csv.csv')

# %%
df
# Out:
#       Unnamed: 0                       date    close     high       low  \
# 0              0  2015-05-27 00:00:00+00:00  132.045  132.260  130.0500
# 1              1  2015-05-28 00:00:00+00:00  131.780  131.950  131.1000
# 2              2  2015-05-29 00:00:00+00:00  130.280  131.450  129.9000
# 3              3  2015-06-01 00:00:00+00:00  130.535  131.390  130.0500
# 4              4  2015-06-02 00:00:00+00:00  129.960  130.655  129.3200
# ...          ...                        ...      ...      ...       ...
# 1253        1253  2020-05-18 00:00:00+00:00  314.960  316.500  310.3241
# 1254        1254  2020-05-19 00:00:00+00:00  313.140  318.520  313.0100
# 1255        1255  2020-05-20 00:00:00+00:00  319.230  319.520  316.2000
# 1256        1256  2020-05-21 00:00:00+00:00  316.850  320.890  315.8700
# 1257        1257  2020-05-22 00:00:00+00:00  318.890  319.230  315.3500
#
#         open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       date    close     high     low    open  \
# 0           0  2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34
# 1           1  2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86
# 2           2  2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23
# 3           3  2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20
# 4           4  2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86
#
#      volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0  45833246  121.682558  121.880685  119.844118  120.111360   45833246
# 1  30733309  121.438354  121.595013  120.811718  121.512076   30733309
# 2  50884452  120.056069  121.134251  119.705890  120.931516   50884452
# 3  32112797  120.291057  121.078960  119.844118  120.903870   32112797
# 4  33667627  119.761181  120.401640  119.171406  119.669029   33667627
#
#    divCash  splitFactor
# 0      0.0            1
# 1      0.0            1
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                       date   close    high       low    open  \
# 1253        1253  2020-05-18 00:00:00+00:00  314.96  316.50  310.3241  313.17
# 1254        1254  2020-05-19 00:00:00+00:00  313.14  318.52  313.0100  315.03
# 1255        1255  2020-05-20 00:00:00+00:00  319.23  319.52  316.2000  316.68
# 1256        1256  2020-05-21 00:00:00+00:00  316.85  320.89  315.8700  318.66
# 1257        1257  2020-05-22 00:00:00+00:00  318.89  319.23  315.3500  315.77
#
#         volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 1253  33843125    314.96   316.50  310.3241   313.17   33843125      0.0
# 1254  25432385    313.14   318.52  313.0100   315.03   25432385      0.0
# 1255  27876215    319.23   319.52  316.2000   316.68   27876215      0.0
# 1256  25672211    316.85   320.89  315.8700   318.66   25672211      0.0
# 1257  20450754    318.89   319.23  315.3500   315.77   20450754      0.0
#
#       splitFactor
# 1253            1
# 1254            1
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#                            date    close     high       low    open    volume  \
# 0     2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34  45833246
# 1     2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86  30733309
# 2     2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23  50884452
# 3     2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20  32112797
# 4     2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86  33667627
# ...                         ...      ...      ...       ...     ...       ...
# 1253  2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17  33843125
# 1254  2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03  25432385
# 1255  2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68  27876215
# 1256  2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66  25672211
# 1257  2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77  20450754
#
# ...

# %%
df['Date']= pd.to_datetime(df.date)

# %%
df
# Out:
#                            date    close     high       low    open    volume  \
# 0     2015-05-27 00:00:00+00:00  132.045  132.260  130.0500  130.34  45833246
# 1     2015-05-28 00:00:00+00:00  131.780  131.950  131.1000  131.86  30733309
# 2     2015-05-29 00:00:00+00:00  130.280  131.450  129.9000  131.23  50884452
# 3     2015-06-01 00:00:00+00:00  130.535  131.390  130.0500  131.20  32112797
# 4     2015-06-02 00:00:00+00:00  129.960  130.655  129.3200  129.86  33667627
# ...                         ...      ...      ...       ...     ...       ...
# 1253  2020-05-18 00:00:00+00:00  314.960  316.500  310.3241  313.17  33843125
# 1254  2020-05-19 00:00:00+00:00  313.140  318.520  313.0100  315.03  25432385
# 1255  2020-05-20 00:00:00+00:00  319.230  319.520  316.2000  316.68  27876215
# 1256  2020-05-21 00:00:00+00:00  316.850  320.890  315.8700  318.66  25672211
# 1257  2020-05-22 00:00:00+00:00  318.890  319.230  315.3500  315.77  20450754
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1258 non-null   object
#  1   close        1258 non-null   float64
#  2   high         1258 non-null   float64
#  3   low          1258 non-null   float64
#  4   open         1258 non-null   float64
#  5   volume       1258 non-null   int64
#  6   adjClose     1258 non-null   float64
#  7   adjHigh      1258 non-null   float64
#  8   adjLow       1258 non-null   float64
#  9   adjOpen      1258 non-null   float64
#  10  adjVolume    1258 non-null   int64
#  11  divCash      1258 non-null   float64
#  12  splitFactor  1258 non-null   int64
#  13  Date         1258 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(9), int64(3), object(1)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# Date           0
# dtype: int64

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    167.723998   169.230475   166.039780   167.548266  3.500397e+07
# std      56.850796    57.500128    56.006773    56.612707  1.729100e+07
# min      90.340000    91.670000    89.470000    90.000000  1.136204e+07
# 25%     116.327500   117.405000   115.602500   116.482500  2.359205e+07
# 50%     160.485000   162.080000   158.974250   160.345000  3.064771e+07
# 75%     199.785000   201.277500   198.170000   199.520000  4.100487e+07
# max     327.200000   327.850000   323.350000   324.730000  1.622063e+08
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    162.666715   164.131054   161.028013   162.493082  3.500397e+07
# std      58.733820    59.402842    57.869246    58.494560  1.729100e+07
# ...

# %%
print('The length of dataset is :',len(df))
# Out:
# The length of dataset is : 1258

# %%
print('the shape of dataset is ', df.shape)
# Out:
# the shape of dataset is  (1258, 14)

# %%
df['open'].plot(figsize=(10,4))
plt.show()

# %%
#spliting the dataset 
x= df[['open','high', 'low', 'volume']]
y= df['close']

# %%
print(x)
# Out:
#         open     high       low    volume
# 0     130.34  132.260  130.0500  45833246
# 1     131.86  131.950  131.1000  30733309
# 2     131.23  131.450  129.9000  50884452
# 3     131.20  131.390  130.0500  32112797
# 4     129.86  130.655  129.3200  33667627
# ...      ...      ...       ...       ...
# 1253  313.17  316.500  310.3241  33843125
# 1254  315.03  318.520  313.0100  25432385
# 1255  316.68  319.520  316.2000  27876215
# 1256  318.66  320.890  315.8700  25672211
# 1257  315.77  319.230  315.3500  20450754
#
# [1258 rows x 4 columns]

# %%
print(y)
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 0)

# %%
print('the shape of x_train is :', x_train.shape)
# Out:
# the shape of x_train is : (943, 4)

# %%
print('the shape of y_test is :', y_test.shape)
# Out:
# the shape of y_test is : (315,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix , accuracy_score
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [-5.72199532e-01  6.87109453e-01  8.86463283e-01 -1.08492815e-09]

# %%
print(regressor.intercept_)
# Out:
# 0.11094825488586935

# %%
predicted= regressor.predict(x_test)

# %%
df.head(6)
# Out:
#                         date    close     high     low    open    volume  \
# 0  2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34  45833246
# 1  2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86  30733309
# 2  2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23  50884452
# 3  2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20  32112797
# 4  2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86  33667627
# 5  2015-06-03 00:00:00+00:00  130.120  130.940  129.90  130.66  30983542
#
#      adjClose     adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# 0  121.682558  121.880685  119.844118  120.111360   45833246      0.0
# 1  121.438354  121.595013  120.811718  121.512076   30733309      0.0
# 2  120.056069  121.134251  119.705890  120.931516   50884452      0.0
# 3  120.291057  121.078960  119.844118  120.903870   32112797      0.0
# 4  119.761181  120.401640  119.171406  119.669029   33667627      0.0
# ...

# %%
print(x_test)
# Out:
#          open     high       low    volume
# 5     130.660  130.940  129.9000  30983542
# 494   152.450  154.070  152.3100  25596687
# 52    116.530  119.990  116.5300  54951597
# 985   206.830  207.760  205.1200  18543206
# 186    96.310   96.900   95.9200  34280758
# ...       ...      ...       ...       ...
# 744   186.550  187.400  185.2200  23211241
# 1002  183.520  184.349  180.2839  38612290
# 922   154.110  154.480  151.7400  25441549
# 459   139.845  141.600  139.7600  25860165
# 911   149.560  151.820  148.5200  41025314
#
# [315 rows x 4 columns]

# %%
predicted.shape
# Out:
# (315,)

# %%
dfr=pd.DataFrame({'Actual':y_test,'Pridected': predicted})

# %%
df.head(6)
# Out:
#                         date    close     high     low    open    volume  \
# 0  2015-05-27 00:00:00+00:00  132.045  132.260  130.05  130.34  45833246
# 1  2015-05-28 00:00:00+00:00  131.780  131.950  131.10  131.86  30733309
# 2  2015-05-29 00:00:00+00:00  130.280  131.450  129.90  131.23  50884452
# 3  2015-06-01 00:00:00+00:00  130.535  131.390  130.05  131.20  32112797
# 4  2015-06-02 00:00:00+00:00  129.960  130.655  129.32  129.86  33667627
# 5  2015-06-03 00:00:00+00:00  130.120  130.940  129.90  130.66  30983542
#
#      adjClose     adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# 0  121.682558  121.880685  119.844118  120.111360   45833246      0.0
# 1  121.438354  121.595013  120.811718  121.512076   30733309      0.0
# 2  120.056069  121.134251  119.705890  120.931516   50884452      0.0
# 3  120.291057  121.078960  119.844118  120.903870   32112797      0.0
# 4  119.761181  120.401640  119.171406  119.669029   33667627      0.0
# ...

# %%
dfr
# Out:
#       Actual   Pridected
# 5     130.12  130.435435
# 494   153.95  153.731535
# 52    119.72  119.118748
# 985   205.28  206.328009
# 186    96.88   96.575683
# ...      ...         ...
# 744   187.36  186.296984
# 1002  183.09  181.541997
# 922   152.70  152.558283
# 459   141.42  141.250455
# 911   150.75  150.462761
#
# [315 rows x 2 columns]

# %%
#the accuracy score in % form 
print(regressor.score (x_test,y_test)*100)
# Out:
# 99.93380579129287

# %%
graph= dfr.head(50)

# %%
graph.plot(kind ='bar', figsize = (10,5))
plt.plot()
# Out:
# []

# %% [markdown]
# #frorm above graph it is clear that my actual and predicted point is almost same and accuracy level is 99.9%
